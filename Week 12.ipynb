# %% [markdown]
# My url: https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=8318f7a3242a4e4db1b64c107b5e763b
# Import thingies first

# %%
import pandas as pd
import numpy as np
import json
import requests
from urllib2 import Request, urlopen

# %%
#myurl="https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=8318f7a3242a4e4db1b64c107b5e763b"
#response = requests.get(myurl)

# %%
response = urlopen("https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=8318f7a3242a4e4db1b64c107b5e763b")
jsondata = response.read().decode('utf-8', 'replace')

# %%
from urllib2 import Request, urlopen
import json
from pandas.io.json import json_normalize


request=Request('https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=8318f7a3242a4e4db1b64c107b5e763b')
response = urlopen(request)
hits = response.read()
data = json.loads(hits)
json_normalize(data['response'], ['docs'])
# Out:
#                            _id abstract blog  \
# 0     5a4c1bfc95d0e0246f21ef48      NaN   []
# 1     5a4c1bf595d0e0246f21ef47      NaN   []
# 2     5a4c194f95d0e0246f21ef46      NaN   []
# 3     5a4c192595d0e0246f21ef45      NaN   []
# 4     5a4c172895d0e0246f21ef3e      NaN   []
# 5     5a4c14da95d0e0246f21ef3c      NaN   []
# 6     5a4c149195d0e0246f21ef39      NaN   []
# 7     5a4c129095d0e0246f21ef37      NaN   []
# 8     5a4c128695d0e0246f21ef36      NaN   []
# 9     5a4c0ef495d0e0246f21ef2e      NaN   []
# 10    5a4c0c5295d0e0246f21ef26      NaN   []
# 11    5a4c0b0f95d0e0246f21ef25      NaN   []
# 12    5a4c0a4795d0e0246f21ef23      NaN   []
# 13    5a4c0a1295d0e0246f21ef1f      NaN   []
# 14    5a4c097f95d0e0246f21ef1e      NaN   []
# 15    5a4c07d595d0e0246f21ef1b      NaN   []
# 16    5a4c079595d0e0246f21ef1a      NaN   []
# 17    5a4c03b095d0e0246f21ef11      NaN   []
# 18    5a4c038e95d0e0246f21ef10      NaN   []
# 19    5a4c02fc95d0e0246f21ef0f      NaN   []
# ...

# %%
#r = requests.get('https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=8318f7a3242a4e4db1b64c107b5e763b')
#x = r.json()
##x.keys()
#df = pd.DataFrame(x['docs'])
#print df
